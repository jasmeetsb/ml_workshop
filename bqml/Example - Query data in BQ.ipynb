# %%
#!pip install -U google-cloud
#!pip install -U google-cloud-bigquery

# %%
# Note I have set up GOOGLE_APPLICATION_CREDENTIALS environment variables# Note  
# per https://google-cloud-python.readthedocs.io/en/latest/bigquery/usage.html#id3

from google.cloud import bigquery
client = bigquery.Client()
# %load_ext google.cloud.bigquery
# Out:
# /home/jasmeetbhatia/anaconda3/envs/tf19gpu/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /home/jasmeetbhatia/anaconda3/envs/tf19gpu/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery df2
# SELECT
#   arr_delay,
#   carrier,
#   origin,
#   dest,
#   dep_delay,
#   taxi_out,
#   distance
# FROM
#   `cloud-training-demos.flights.tzcorr` LIMIT 1000
# Out:
#      arr_delay carrier origin dest  dep_delay  taxi_out  distance
# 0        -21.0      WN    ABQ  OAK       -5.0      14.0     889.0
# 1         15.0      WN    ABQ  OAK       28.0       9.0     889.0
# 2         28.0      WN    ABQ  OAK       56.0       6.0     889.0
# 3        -11.0      NK    ACY  MYR       -8.0      10.0     466.0
# 4        -22.0      NK    ACY  MYR      -10.0       8.0     466.0
# 5        -12.0      NK    ACY  MYR       -9.0       9.0     466.0
# 6        -13.0      NK    ACY  MYR       -5.0      11.0     466.0
# 7         -9.0      NK    ACY  MYR       -6.0       9.0     466.0
# 8          0.0      NK    ACY  PBI       -7.0       9.0     936.0
# 9        -24.0      NK    ACY  PBI      -16.0       9.0     936.0
# 10       -11.0      NK    ACY  PBI       -9.0       9.0     936.0
# 11       -11.0      NK    ACY  FLL        3.0      10.0     977.0
# 12        -8.0      NK    ACY  FLL      -10.0      10.0     977.0
# 13       -13.0      NK    ACY  FLL       -8.0       8.0     977.0
# 14       -14.0      NK    ACY  FLL       -2.0      11.0     977.0
# 15       -16.0      AS    ADK  ANC      -19.0       4.0    1192.0
# 16        -4.0      AS    ADK  ANC        8.0       4.0    1192.0
# 17       -10.0      AS    ADQ  ANC       -9.0       4.0     253.0
# 18       -14.0      AS    ADQ  ANC      -20.0      14.0     253.0
# 19       -13.0      AS    ADQ  ANC      -14.0       9.0     253.0
# 20        -9.0      AS    ADQ  ANC      -11.0       9.0     253.0
# 21       -20.0      AS    ADQ  ANC      -23.0       9.0     253.0
# 22         NaN      AS    ADQ  ANC        NaN       NaN     253.0
# 23       -14.0      AS    AKN  ANC       -9.0       4.0     288.0
# 24       -27.0      WN    ALB  FLL       -3.0      20.0    1204.0
# 25       -24.0      WN    ALB  FLL        0.0      23.0    1204.0
# 26        -9.0      AS    ANC  CDV      -11.0      11.0     160.0
# 27         8.0      AS    ANC  CDV       13.0      10.0     160.0
# 28        -4.0      AS    ANC  CDV       -3.0      12.0     160.0
# 29         4.0      AS    ANC  CDV       -1.0      17.0     160.0
# ..         ...     ...    ...  ...        ...       ...       ...
# 970       10.0      AS    WRG  KTN       11.0       8.0      82.0
# 971       29.0      AS    WRG  KTN       27.0       6.0      82.0
# 972       49.0      AS    WRG  KTN       47.0       9.0      82.0
# 973       -2.0      AS    WRG  KTN       -6.0      13.0      82.0
# 974      -14.0      OO    XNA  CVG      -10.0      12.0     562.0
# 975       -7.0      EV    XNA  CVG       -8.0      13.0     562.0
# 976       -1.0      EV    XNA  CVG        0.0      14.0     562.0
# 977       -9.0      OO    XNA  CVG        3.0       8.0     562.0
# 978        5.0      OO    XNA  CVG       -5.0      18.0     562.0
# 979        3.0      OO    XNA  CVG       -1.0      17.0     562.0
# 980      -13.0      OO    XNA  CVG      -15.0      15.0     562.0
# 981        5.0      AS    YAK  CDV       -9.0      20.0     213.0
# 982      -31.0      AS    YAK  CDV      -21.0      10.0     213.0
# 983       -6.0      AS    YAK  CDV      -21.0      16.0     213.0
# 984      -11.0      AS    YAK  CDV       -7.0       4.0     213.0
# 985      -29.0      AS    YAK  CDV      -26.0       5.0     213.0
# 986      -19.0      AS    YAK  CDV      -16.0       5.0     213.0
# 987      -21.0      AS    YAK  CDV      -18.0       4.0     213.0
# 988      -26.0      AS    YAK  CDV      -23.0       8.0     213.0
# 989       27.0      AS    YAK  CDV       22.0       6.0     213.0
# 990      -15.0      AS    YAK  CDV      -18.0       8.0     213.0
# 991       26.0      AS    YAK  JNU       25.0       5.0     199.0
# 992       -4.0      AS    YAK  JNU       -9.0       9.0     199.0
# 993      -20.0      AS    YAK  JNU      -19.0       4.0     199.0
# 994      -24.0      AS    YAK  JNU      -23.0       8.0     199.0
# 995      -13.0      AS    YAK  JNU      -22.0      14.0     199.0
# 996       -6.0      AS    YAK  JNU       -2.0       4.0     199.0
# 997      -12.0      AS    YAK  JNU      -21.0      16.0     199.0
# 998       14.0      AS    YAK  JNU        6.0      16.0     199.0
# 999      -20.0      AS    YAK  JNU      -20.0       6.0     199.0
#
# [1000 rows x 7 columns]

# %%
df2
# Out:
#      arr_delay carrier origin dest  dep_delay  taxi_out  distance
# 0        -21.0      WN    ABQ  OAK       -5.0      14.0     889.0
# 1         15.0      WN    ABQ  OAK       28.0       9.0     889.0
# 2         28.0      WN    ABQ  OAK       56.0       6.0     889.0
# 3        -11.0      NK    ACY  MYR       -8.0      10.0     466.0
# 4        -22.0      NK    ACY  MYR      -10.0       8.0     466.0
# 5        -12.0      NK    ACY  MYR       -9.0       9.0     466.0
# 6        -13.0      NK    ACY  MYR       -5.0      11.0     466.0
# 7         -9.0      NK    ACY  MYR       -6.0       9.0     466.0
# 8          0.0      NK    ACY  PBI       -7.0       9.0     936.0
# 9        -24.0      NK    ACY  PBI      -16.0       9.0     936.0
# 10       -11.0      NK    ACY  PBI       -9.0       9.0     936.0
# 11       -11.0      NK    ACY  FLL        3.0      10.0     977.0
# 12        -8.0      NK    ACY  FLL      -10.0      10.0     977.0
# 13       -13.0      NK    ACY  FLL       -8.0       8.0     977.0
# 14       -14.0      NK    ACY  FLL       -2.0      11.0     977.0
# 15       -16.0      AS    ADK  ANC      -19.0       4.0    1192.0
# 16        -4.0      AS    ADK  ANC        8.0       4.0    1192.0
# 17       -10.0      AS    ADQ  ANC       -9.0       4.0     253.0
# 18       -14.0      AS    ADQ  ANC      -20.0      14.0     253.0
# 19       -13.0      AS    ADQ  ANC      -14.0       9.0     253.0
# 20        -9.0      AS    ADQ  ANC      -11.0       9.0     253.0
# 21       -20.0      AS    ADQ  ANC      -23.0       9.0     253.0
# 22         NaN      AS    ADQ  ANC        NaN       NaN     253.0
# 23       -14.0      AS    AKN  ANC       -9.0       4.0     288.0
# 24       -27.0      WN    ALB  FLL       -3.0      20.0    1204.0
# 25       -24.0      WN    ALB  FLL        0.0      23.0    1204.0
# 26        -9.0      AS    ANC  CDV      -11.0      11.0     160.0
# 27         8.0      AS    ANC  CDV       13.0      10.0     160.0
# 28        -4.0      AS    ANC  CDV       -3.0      12.0     160.0
# 29         4.0      AS    ANC  CDV       -1.0      17.0     160.0
# ..         ...     ...    ...  ...        ...       ...       ...
# 970       10.0      AS    WRG  KTN       11.0       8.0      82.0
# 971       29.0      AS    WRG  KTN       27.0       6.0      82.0
# 972       49.0      AS    WRG  KTN       47.0       9.0      82.0
# 973       -2.0      AS    WRG  KTN       -6.0      13.0      82.0
# 974      -14.0      OO    XNA  CVG      -10.0      12.0     562.0
# 975       -7.0      EV    XNA  CVG       -8.0      13.0     562.0
# 976       -1.0      EV    XNA  CVG        0.0      14.0     562.0
# 977       -9.0      OO    XNA  CVG        3.0       8.0     562.0
# 978        5.0      OO    XNA  CVG       -5.0      18.0     562.0
# 979        3.0      OO    XNA  CVG       -1.0      17.0     562.0
# 980      -13.0      OO    XNA  CVG      -15.0      15.0     562.0
# 981        5.0      AS    YAK  CDV       -9.0      20.0     213.0
# 982      -31.0      AS    YAK  CDV      -21.0      10.0     213.0
# 983       -6.0      AS    YAK  CDV      -21.0      16.0     213.0
# 984      -11.0      AS    YAK  CDV       -7.0       4.0     213.0
# 985      -29.0      AS    YAK  CDV      -26.0       5.0     213.0
# 986      -19.0      AS    YAK  CDV      -16.0       5.0     213.0
# 987      -21.0      AS    YAK  CDV      -18.0       4.0     213.0
# 988      -26.0      AS    YAK  CDV      -23.0       8.0     213.0
# 989       27.0      AS    YAK  CDV       22.0       6.0     213.0
# 990      -15.0      AS    YAK  CDV      -18.0       8.0     213.0
# 991       26.0      AS    YAK  JNU       25.0       5.0     199.0
# 992       -4.0      AS    YAK  JNU       -9.0       9.0     199.0
# 993      -20.0      AS    YAK  JNU      -19.0       4.0     199.0
# 994      -24.0      AS    YAK  JNU      -23.0       8.0     199.0
# 995      -13.0      AS    YAK  JNU      -22.0      14.0     199.0
# 996       -6.0      AS    YAK  JNU       -2.0       4.0     199.0
# 997      -12.0      AS    YAK  JNU      -21.0      16.0     199.0
# 998       14.0      AS    YAK  JNU        6.0      16.0     199.0
# 999      -20.0      AS    YAK  JNU      -20.0       6.0     199.0
#
# [1000 rows x 7 columns]
